# %%
! pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (2.3.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: pillow in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
! python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (25.2)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000238E48C2810>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000238E48C3150>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000238E48C3890>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000238E48CC8D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000238E48CD510>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
! pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vivek\desktop\deep learning\.env\lib\site-packages (from scikit-learn) (3.6.0)

# %%
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2, ResNet50
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import os

# Define constants
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 20
DATASET_PATH = "dataset/dataset"  # Update with actual dataset path

# Data augmentation and preprocessing
datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Define model function
def build_model(base_model):
    base_model.trainable = False  # Freeze base model layers
    inputs = tf.keras.Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(train_generator.num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Train and evaluate models
models = {
    "MobileNetV2": MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    "ResNet50": ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
}

results = {}

for name, base_model in models.items():
    print(f"Training {name}...")
    model = build_model(base_model)
    history = model.fit(train_generator, validation_data=val_generator, epochs=EPOCHS)
    results[name] = history
    model.save(f"{name}_millet_model.keras")

# Plot accuracy comparison
plt.figure(figsize=(10, 5))
for name, history in results.items():
    plt.plot(history.history['val_accuracy'], label=f"{name} Val Accuracy")
plt.legend()
plt.title("Model Accuracy Comparison")
plt.show()
# Out:
# Found 5869 images belonging to 14 classes.
# Found 1462 images belonging to 14 classes.
# Training MobileNetV2...
# c:\Users\Vivek\Desktop\Deep learning\.env\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 306s 2s/step - accuracy: 0.5168 - loss: 1.5995 - val_accuracy: 0.6765 - val_loss: 1.1170
# Epoch 2/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 283s 2s/step - accuracy: 0.7115 - loss: 0.9479 - val_accuracy: 0.7585 - val_loss: 0.8478
# Epoch 3/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.7797 - loss: 0.7146 - val_accuracy: 0.7907 - val_loss: 0.7171
# Epoch 4/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.8027 - loss: 0.6235 - val_accuracy: 0.8044 - val_loss: 0.6527
# Epoch 5/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.8349 - loss: 0.5309 - val_accuracy: 0.8222 - val_loss: 0.6105
# Epoch 6/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 290s 2s/step - accuracy: 0.8504 - loss: 0.4724 - val_accuracy: 0.8345 - val_loss: 0.5674
# Epoch 7/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 281s 2s/step - accuracy: 0.8518 - loss: 0.4521 - val_accuracy: 0.8358 - val_loss: 0.5426
# Epoch 8/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.8673 - loss: 0.4117 - val_accuracy: 0.8434 - val_loss: 0.5137
# Epoch 9/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.8785 - loss: 0.3813 - val_accuracy: 0.8591 - val_loss: 0.4995
# Epoch 10/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 337s 2s/step - accuracy: 0.8898 - loss: 0.3505 - val_accuracy: 0.8523 - val_loss: 0.4959
# Epoch 11/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 309s 2s/step - accuracy: 0.8962 - loss: 0.3332 - val_accuracy: 0.8618 - val_loss: 0.4695
# Epoch 12/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 291s 2s/step - accuracy: 0.8952 - loss: 0.3220 - val_accuracy: 0.8618 - val_loss: 0.4574
# Epoch 13/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.9029 - loss: 0.3061 - val_accuracy: 0.8557 - val_loss: 0.4617
# Epoch 14/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.9123 - loss: 0.2820 - val_accuracy: 0.8632 - val_loss: 0.4444
# Epoch 15/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.9160 - loss: 0.2661 - val_accuracy: 0.8741 - val_loss: 0.4257
# Epoch 16/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9090 - loss: 0.2756 - val_accuracy: 0.8618 - val_loss: 0.4384
# Epoch 17/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.9141 - loss: 0.2608 - val_accuracy: 0.8687 - val_loss: 0.4162
# Epoch 18/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 290s 2s/step - accuracy: 0.9230 - loss: 0.2417 - val_accuracy: 0.8598 - val_loss: 0.4555
# Epoch 19/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9213 - loss: 0.2396 - val_accuracy: 0.8837 - val_loss: 0.3812
# Epoch 20/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.9233 - loss: 0.2325 - val_accuracy: 0.8714 - val_loss: 0.4208
# Training ResNet50...
# Epoch 1/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 495s 3s/step - accuracy: 0.2404 - loss: 2.3611 - val_accuracy: 0.3126 - val_loss: 2.0539
# Epoch 2/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 492s 3s/step - accuracy: 0.2897 - loss: 2.1144 - val_accuracy: 0.3126 - val_loss: 2.0354
# Epoch 3/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 484s 3s/step - accuracy: 0.2973 - loss: 2.0711 - val_accuracy: 0.3126 - val_loss: 2.0112
# Epoch 4/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 479s 3s/step - accuracy: 0.3009 - loss: 2.0452 - val_accuracy: 0.3133 - val_loss: 1.9913
# Epoch 5/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 480s 3s/step - accuracy: 0.3096 - loss: 2.0195 - val_accuracy: 0.3140 - val_loss: 1.9765
# Epoch 6/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 479s 3s/step - accuracy: 0.3093 - loss: 1.9936 - val_accuracy: 0.3160 - val_loss: 1.9719
# Epoch 7/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 482s 3s/step - accuracy: 0.3150 - loss: 1.9797 - val_accuracy: 0.3140 - val_loss: 1.9625
# Epoch 8/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 509s 3s/step - accuracy: 0.3132 - loss: 1.9681 - val_accuracy: 0.3413 - val_loss: 1.9490
# Epoch 9/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 531s 3s/step - accuracy: 0.3249 - loss: 1.9480 - val_accuracy: 0.3228 - val_loss: 1.9365
# Epoch 10/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 480s 3s/step - accuracy: 0.3280 - loss: 1.9342 - val_accuracy: 0.3564 - val_loss: 1.9437
# Epoch 11/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 478s 3s/step - accuracy: 0.3299 - loss: 1.9327 - val_accuracy: 0.3605 - val_loss: 1.9236
# Epoch 12/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 480s 3s/step - accuracy: 0.3317 - loss: 1.9175 - val_accuracy: 0.3687 - val_loss: 1.9228
# Epoch 13/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 481s 3s/step - accuracy: 0.3333 - loss: 1.9023 - val_accuracy: 0.3591 - val_loss: 1.9088
# Epoch 14/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 480s 3s/step - accuracy: 0.3413 - loss: 1.8956 - val_accuracy: 0.3570 - val_loss: 1.8974
# Epoch 15/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 478s 3s/step - accuracy: 0.3449 - loss: 1.8883 - val_accuracy: 0.3728 - val_loss: 1.8843
# Epoch 16/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 477s 3s/step - accuracy: 0.3496 - loss: 1.8785 - val_accuracy: 0.3317 - val_loss: 1.8832
# Epoch 17/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 486s 3s/step - accuracy: 0.3518 - loss: 1.8710 - val_accuracy: 0.3666 - val_loss: 1.8711
# Epoch 18/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 478s 3s/step - accuracy: 0.3484 - loss: 1.8679 - val_accuracy: 0.3461 - val_loss: 1.8800
# Epoch 19/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 482s 3s/step - accuracy: 0.3537 - loss: 1.8523 - val_accuracy: 0.3659 - val_loss: 1.8754
# Epoch 20/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 481s 3s/step - accuracy: 0.3580 - loss: 1.8444 - val_accuracy: 0.3912 - val_loss: 1.8731

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define image size and batch size
IMG_SIZE = (224, 224)  # Adjust based on your model input size
BATCH_SIZE = 32  

# Define validation data directory
val_dir = "dataset/dataset"  # Change this to your validation dataset path

# Create validation data generator
val_datagen = ImageDataGenerator(rescale=1.0 / 255.0)

val_data = val_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

# Get class names (assuming folder names represent classes)
class_names = list(val_data.class_indices.keys())
# Out:
# Found 7331 images belonging to 14 classes.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the combined model (Modify the filename accordingly)
from tensorflow.keras.models import load_model

mobilenet_model = load_model("MobileNetV2_millet_model.keras") 
resnet_model = load_model("ResNet50_millet_model.keras")

# Function to evaluate the model
# Get Predictions
def evaluate_model(model, data):
    y_true = []
    y_pred = []
    confidences = []

    for images, labels in data:
        preds = model.predict(images)
        y_pred.extend(np.argmax(preds, axis=1))
        y_true.extend(np.argmax(labels, axis=1))
        confidences.extend(np.max(preds, axis=1))

        if len(y_true) > 1000:  # Limit evaluation set size
            break

    return np.array(y_true), np.array(y_pred), np.array(confidences)

y_true_mobilenet, y_pred_mobilenet, conf_mobilenet = evaluate_model(mobilenet_model,val_generator)
y_true_resnet, y_pred_resnet, conf_resnet = evaluate_model(resnet_model, val_generator)

# Compute Metrics
def compute_metrics(y_true, y_pred):
    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred, average='weighted'),
        "Recall": recall_score(y_true, y_pred, average='weighted'),
        "F1 Score": f1_score(y_true, y_pred, average='weighted'),
        "Confusion Matrix": confusion_matrix(y_true, y_pred)
    }

metrics_mobilenet = compute_metrics(y_true_mobilenet, y_pred_mobilenet)
metrics_resnet = compute_metrics(y_true_resnet, y_pred_resnet)

# Print Classification Reports
print("=== MobileNetV2 Metrics ===")
print(classification_report(y_true_mobilenet, y_pred_mobilenet, target_names=class_names))

print("\n=== ResNet50 Metrics ===")
print(classification_report(y_true_resnet, y_pred_resnet, target_names=class_names))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# === MobileNetV2 Metrics ===
#                             precision    recall  f1-score   support
#
#         Finger(Ragi) downy       0.88      0.85      0.87        34
#        Finger(Ragi) mottle       0.94      0.91      0.93        34
#      Finger(Ragi) seedling       0.68      0.66      0.67        38
#          Finger(Ragi) smut       0.83      0.61      0.70        33
#          Finger(Ragi) wilt       0.93      0.72      0.81        36
#              Pearl_Healthy       0.89      0.95      0.92       195
#         Pearl_Rust_disease       0.92      0.95      0.93       310
# Peral_Downy_disease_mildew       0.87      0.91      0.89       216
#        Sorgum(Jowar) Blast       0.67      0.61      0.64        23
#        Sorgum(Jowar) Ergot       0.92      0.96      0.94        23
#         Sorgum(Jowar) Rust       0.00      0.00      0.00        20
#         Sorgum(Jowar) Smut       0.00      0.00      0.00         1
#       Sorgum(Jowar)Healthy       0.95      0.88      0.91        24
#                    healthy       0.78      0.84      0.81        37
#
#                   accuracy                           0.87      1024
#                  macro avg       0.73      0.70      0.71      1024
#               weighted avg       0.86      0.87      0.86      1024
#
#
# === ResNet50 Metrics ===
#                             precision    recall  f1-score   support
#
#         Finger(Ragi) downy       0.00      0.00      0.00        42
#        Finger(Ragi) mottle       0.00      0.00      0.00        35
#      Finger(Ragi) seedling       0.00      0.00      0.00        35
#          Finger(Ragi) smut       0.18      0.05      0.08        41
#          Finger(Ragi) wilt       0.50      0.10      0.16        42
#              Pearl_Healthy       0.67      0.41      0.51       171
#         Pearl_Rust_disease       0.38      0.60      0.46       319
# Peral_Downy_disease_mildew       0.35      0.61      0.44       199
#        Sorgum(Jowar) Blast       0.00      0.00      0.00        24
#        Sorgum(Jowar) Ergot       0.00      0.00      0.00        30
#         Sorgum(Jowar) Rust       0.00      0.00      0.00        16
#         Sorgum(Jowar) Smut       0.00      0.00      0.00         4
#       Sorgum(Jowar)Healthy       0.57      0.50      0.53        26
#                    healthy       0.11      0.03      0.05        30
#
#                   accuracy                           0.40      1014
#                  macro avg       0.20      0.16      0.16      1014
#               weighted avg       0.34      0.40      0.34      1014
# c:\Users\Vivek\Desktop\Deep learning\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vivek\Desktop\Deep learning\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vivek\Desktop\Deep learning\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vivek\Desktop\Deep learning\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vivek\Desktop\Deep learning\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vivek\Desktop\Deep learning\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vivek\Desktop\Deep learning\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Vivek\Desktop\Deep learning\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# Plot Confusion Matrices
def plot_confusion_matrix(cm, model_name):
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix - {model_name}")
    plt.show()

plot_confusion_matrix(metrics_mobilenet["Confusion Matrix"], "MobileNetV2")
plot_confusion_matrix(metrics_resnet["Confusion Matrix"], "ResNet50")

# Compare Accuracy of Models
plt.figure(figsize=(6, 4))
plt.bar(["MobileNetV2", "ResNet50"], [metrics_mobilenet["Accuracy"], metrics_resnet["Accuracy"]], color=['blue', 'green'])
plt.ylabel("Accuracy")
plt.title("Model Comparison")
plt.show()

# %%
import os
import shutil
import random

# Original Dataset Path (Modify as Needed)
ORIGINAL_DATASET_PATH = "dataset/dataset"

# New Structured Dataset Path
NEW_DATASET_PATH = "Dataset_Modified"

# Define Mapping (1 = Treatable, 0 = Non-Treatable)
stage_mapping = {
    "Finger(Ragi) Downy": 1,
    "Finger(Ragi) Mottle": 1,
    "Finger(Ragi) Seeding": 1,
    "Finger(Ragi) Smut": 0,
    "Finger(Ragi) Wilt": 0,
    "Pearl_Rust_disease": 1,
    "Pearl_Downy_diseases": 1,
    "Sorgum(Jowar) Blast": 1,
    "Sorgum(Jowar) Ergot": 0,
    "Sogum(Jowar) Rust": 1,
    "Sorgum(Jowar) Smut": 0
}

# %%
# Create Directories for Train & Validation Sets
for split in ["Train", "Validation"]:
    for category in ["Treatable", "Non-Treatable"]:
        os.makedirs(os.path.join(NEW_DATASET_PATH, split, category), exist_ok=True)

# %%
# Collect All Image Files
all_images = []
for class_name in os.listdir(ORIGINAL_DATASET_PATH):
    class_path = os.path.join(ORIGINAL_DATASET_PATH, class_name)

    if os.path.isdir(class_path):  # Ensure it's a directory
        label = stage_mapping.get(class_name)  # Get Treatable (1) or Non-Treatable (0)
        if label is not None:
            images = [os.path.join(class_path, img) for img in os.listdir(class_path)]
            all_images.extend([(img, label) for img in images])

# Shuffle Dataset
random.shuffle(all_images)

# Split Dataset (80% Train, 20% Validation)
split_idx = int(0.8 * len(all_images))
train_images = all_images[:split_idx]
val_images = all_images[split_idx:]

# Function to Move Images
def move_images(image_list, dataset_type):
    for img_path, label in image_list:
        category = "Treatable" if label == 1 else "Non-Treatable"
        dest_folder = os.path.join(NEW_DATASET_PATH, dataset_type, category)
        shutil.move(img_path, os.path.join(dest_folder, os.path.basename(img_path)))

# Move Train & Validation Images
move_images(train_images, "Train")
move_images(val_images, "Validation")

print("✅ Dataset organized successfully!")
# Out:
# ✅ Dataset organized successfully!

# %%
# Load Image Data for Stage Classification
stage_data = datagen.flow_from_directory(
    'Dataset_Modified/Train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

val_data = datagen.flow_from_directory(
    'Dataset_Modified/Validation',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

# Print class mapping
print("Class Mapping for Training Data:", stage_data.class_indices)
print("Class Mapping for Validation Data:", val_data.class_indices)

# ------------------------------------------------
# 1. Define the model (or load a saved one)
# ------------------------------------------------
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

stage_model = Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=(*IMG_SIZE, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation="relu"),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(1, activation="sigmoid")  # Binary classification
])

stage_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# ------------------------------------------------
# 2. Train the model
# ------------------------------------------------
history_stage = stage_model.fit(stage_data, epochs=10, validation_data=val_data)

# Save the trained model
stage_model.save("millet_disease_app/models/stage_classification_model.keras")

# ------------------------------------------------
# 3. Evaluate the model
# ------------------------------------------------
y_true_stage = []
y_pred_stage = []

for images, labels in val_data:
    preds = stage_model.predict(images)
    y_pred_stage.extend((preds > 0.5).astype(int).flatten())  # binary threshold
    y_true_stage.extend(labels.astype(int).flatten())

    if len(y_true_stage) > 1000:  # optional limit
        break

y_true_stage = np.array(y_true_stage)
y_pred_stage = np.array(y_pred_stage)

# Compute Metrics
stage_metrics = {
    "Accuracy": accuracy_score(y_true_stage, y_pred_stage),
    "Precision": precision_score(y_true_stage, y_pred_stage),
    "Recall": recall_score(y_true_stage, y_pred_stage),
    "F1 Score": f1_score(y_true_stage, y_pred_stage),
    "Confusion Matrix": confusion_matrix(y_true_stage, y_pred_stage)
}

# Print Classification Report
print("=== Disease Stage Classification Metrics ===")
print(classification_report(y_true_stage, y_pred_stage, target_names=["Non-Treatable", "Treatable"]))

# Plot Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(stage_metrics["Confusion Matrix"], annot=True, fmt="d", cmap="Oranges",
            xticklabels=["Non-Treatable", "Treatable"],
            yticklabels=["Non-Treatable", "Treatable"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Disease Stage Classification")
plt.show()

# %%
# Load Image Data for Stage Classification
stage_data = datagen.flow_from_directory(
    'Dataset_Modified/Train',  # ✅ Now it correctly maps 'Treatable' and 'Non-Treatable'
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

val_data = datagen.flow_from_directory(
    'Dataset_Modified/Validation',  # ✅ Validation data
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

# Print class mapping
print("Class Mapping for Training Data:", stage_data.class_indices)
print("Class Mapping for Validation Data:", val_data.class_indices)
# Out:
# Found 2136 images belonging to 2 classes.
# Found 534 images belonging to 2 classes.
# Class Mapping for Training Data: {'Non-Treatable': 0, 'Treatable': 1}
# Class Mapping for Validation Data: {'Non-Treatable': 0, 'Treatable': 1}

# %%
# Get Predictions
y_true_stage = []
y_pred_stage = []

for images, labels in val_data:
    preds = stage_model.predict(images)
    y_pred_stage.extend((preds > 0.5).astype(int).flatten())  # Convert predictions to binary format
    y_true_stage.extend(labels.astype(int).flatten())  # Directly use labels

    if len(y_true_stage) > 1000:  # Limit evaluation set
        break

y_true_stage = np.array(y_true_stage)
y_pred_stage = np.array(y_pred_stage)

# Compute Metrics
stage_metrics = {
    "Accuracy": accuracy_score(y_true_stage, y_pred_stage),
    "Precision": precision_score(y_true_stage, y_pred_stage),
    "Recall": recall_score(y_true_stage, y_pred_stage),
    "F1 Score": f1_score(y_true_stage, y_pred_stage),
    "Confusion Matrix": confusion_matrix(y_true_stage, y_pred_stage)
}

# Print Classification Report
print("=== Disease Stage Classification Metrics ===")
print(classification_report(y_true_stage, y_pred_stage, target_names=["Non-Treatable", "Treatable"]))

# Plot Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(stage_metrics["Confusion Matrix"], annot=True, fmt="d", cmap="Oranges", xticklabels=["Non-Treatable", "Treatable"], yticklabels=["Non-Treatable", "Treatable"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Disease Stage Classification")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 6
#       3 y_pred_stage = []
#       5 for images, labels in val_data:
# ----> 6     preds = stage_model.predict(images)
#       7     y_pred_stage.extend((preds > 0.5).astype(int).flatten())  # Convert predictions to binary format
#       8     y_true_stage.extend(labels.astype(int).flatten())  # Directly use labels
#
# NameError: name 'stage_model' is not defined

# %%
history_stage = stage_model.fit(stage_data, epochs=10, validation_data=val_data)
# Out:
# Epoch 1/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 40s 582ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 9.5842e-04
# Epoch 2/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 1.0000 - loss: 5.2454e-04 - val_accuracy: 1.0000 - val_loss: 6.1468e-04
# Epoch 3/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 1.0000 - loss: 3.3977e-04 - val_accuracy: 1.0000 - val_loss: 4.8493e-04
# Epoch 4/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 1.0000 - loss: 3.6579e-04 - val_accuracy: 1.0000 - val_loss: 4.2153e-04
# Epoch 5/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 1.0000 - loss: 1.9997e-04 - val_accuracy: 1.0000 - val_loss: 4.1432e-04
# Epoch 6/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 1.0000 - loss: 2.0710e-04 - val_accuracy: 1.0000 - val_loss: 3.1254e-04
# Epoch 7/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 1.0000 - loss: 1.6461e-04 - val_accuracy: 1.0000 - val_loss: 2.6026e-04
# Epoch 8/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 1.0000 - loss: 1.7279e-04 - val_accuracy: 1.0000 - val_loss: 2.4618e-04
# Epoch 9/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 1.0000 - loss: 2.7562e-04 - val_accuracy: 1.0000 - val_loss: 1.3851e-04
# Epoch 10/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 1.0000 - loss: 1.8329e-04 - val_accuracy: 1.0000 - val_loss: 1.2747e-04

# %%
stage_model.save("millet_disease_app/models/stage_classification_model.keras")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 stage_model.save("millet_disease_app/models/stage_classification_model.h5")
#
# NameError: name 'stage_model' is not defined
